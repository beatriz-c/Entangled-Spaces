# %%
#original imbalanced dataset plot

# %%
#original frauds before synthetic generation
import pandas as pd

fraudsb = pd.read_csv(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Transfers/Datasets/0frauds_transfers_nd_corr.csv')

# %%
#how many frauds existed originally
len(fraudsb)
# Out:
# 569

# %%
#reduced amount of original nonfrauds 
nfraudsb = pd.read_csv(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Transfers/Datasets/0nonfrauds_transfers_nd_corr.csv', 
                       nrows = 10000)

# %%
#concat dataframe
ub_sample = pd.concat([fraudsb, nfraudsb], ignore_index = True)

# %%
#class ratios
ub_sample['is_fraud'].value_counts()/ub_sample.shape[0]
# Out:
# 0    0.946163
# 1    0.053837
# Name: is_fraud, dtype: float64

# %%
#plot
import seaborn as sns
import matplotlib.pylab as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

#variables
X = ub_sample[['amount', 'accountbalance', 'hour', 'week']]
y = ub_sample['is_fraud']

#scale data before PCA
pca = PCA()
pipe = Pipeline([('scaler', StandardScaler()), ('pca', pca)])
Xt = pipe.fit_transform(X)

#plot
sns.scatterplot(x = Xt[:, 0], y = Xt[:, 1], c = y, style = y, linewidth = 0.25, size = y, hue = y, sizes = {0: 50, 1:150},
                palette = {0: 'Blue', 1: 'Red'})

#legend
plt.xlabel('Component 1', fontsize = 14)
plt.ylabel('Component 2', fontsize = 14)
plt.yticks(ticks = (np.arange(-2, 3, step = 1)), fontsize = 13)
plt.xticks(ticks = (np.arange(-0.5, 3, step = 0.5)), fontsize = 13)
plt.legend(title = '')

#zoom
plt.xlim([-0.5, 2])
plt.ylim([-2, 2])

#save
plt.savefig(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Transfers/Profiles/imbalanced_distribution.png')

# %%
#rund plot  - 10/90

# %%
#rund 10-90
import pandas as pd

rund_10_90 = pd.read_csv(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Transfers/Datasets/2transfers_rund_10-90.csv')

# %%
#class ratios
rund_10_90['is_fraud'].value_counts()/rund_10_90.shape[0]
# Out:
# 0    0.909091
# 1    0.090909
# Name: is_fraud, dtype: float64

# %%
#plot 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

#variables
X = rund_10_90[['amount', 'accountbalance', 'hour', 'week']]
y = rund_10_90['is_fraud']

#scale data before PCA
pca = PCA()
pipe = Pipeline([('scaler', StandardScaler()), ('pca', pca)])
Xt = pipe.fit_transform(X)

#plot
sns.scatterplot(x = Xt[:, 0], y = Xt[:, 1], c = y, style = y, linewidth = 0.25, size = y, hue = y, sizes = {0: 50, 1:50},
                palette = {0: 'Blue', 1: 'Red'})

#legend
plt.xlabel('Component 1', fontsize = 14)
plt.ylabel('Component 2', fontsize = 14)
plt.yticks(ticks = (np.arange(-2, 3, step = 1)), fontsize = 13)
plt.xticks(ticks = (np.arange(-0.5, 3, step = 0.5)), fontsize = 13)
plt.legend(title = '')

#zoom
plt.xlim([-0.5, 2])
plt.ylim([-2, 2])

#save
plt.savefig(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Transfers/Profiles/rund_10-90.png')

# %%
#balanced dataset plot - gan

# %%
#gan and rund - 50/50
import pandas as pd

gro = pd.read_csv(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Transfers/Datasets/2transfers_balanced_gans+rund.csv')

# %%
#select sample to plot
gr = gro.sample(n = 14000)

# %%
#class ratios
gr['is_fraud'].value_counts()/gr.shape[0]
# Out:
# 1    0.500643
# 0    0.499357
# Name: is_fraud, dtype: float64

# %%
#plot 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

#variables
X = gr[['amount', 'accountbalance', 'hour', 'week']]
y = gr['is_fraud']

#scale data before PCA
pca = PCA()
pipe = Pipeline([('scaler', StandardScaler()), ('pca', pca)])
Xt = pipe.fit_transform(X)

#plot
sns.scatterplot(x = Xt[:, 0], y = Xt[:, 1], c = y, style = y, linewidth = 0.25, size = y, hue = y, sizes = {0: 50, 1:50},
                palette = {0: 'Blue', 1: 'Red'})

#legend
plt.xlabel('Component 1', fontsize = 14)
plt.ylabel('Component 2', fontsize = 14)
plt.yticks(ticks = (np.arange(-2, 3, step = 1)), fontsize = 13)
plt.xticks(ticks = (np.arange(-0.5, 3, step = 0.5)), fontsize = 13)
plt.legend(title = '')

#zoom
plt.xlim([-0.5, 2])
plt.ylim([-2, 2])

#save
plt.savefig(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Transfers/Profiles/gan+rund.png')

# %%
#balanced dataset plot - smote

# %%
#smote and rund - 50/50
import pandas as pd

sro = pd.read_csv(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Transfers/Datasets/2transfers_balanced_smote+rund-1M.csv',
                 low_memory = False)

# %%
#select sample to plot
sr = sro.sample(n = 14000)

# %%
#class ratios
sr['is_fraud'].value_counts()/sr.shape[0]
# Out:
# 0    0.509
# 1    0.491
# Name: is_fraud, dtype: float64

# %%
#plot 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

#variables
X = sr[['amount', 'accountbalance', 'hour', 'week']]
y = sr['is_fraud']

#scale data before PCA
pca = PCA()
pipe = Pipeline([('scaler', StandardScaler()), ('pca', pca)])
Xt = pipe.fit_transform(X)

#plot
sns.scatterplot(x = Xt[:, 0], y = Xt[:, 1], c = y, style = y, linewidth = 0.25, size = y, hue = y, sizes = {0: 50, 1:110},
                palette = {0: 'Blue', 1: 'Red'})

#legend
plt.xlabel('Component 1', fontsize = 14)
plt.ylabel('Component 2', fontsize = 14)
plt.yticks(ticks = (np.arange(-2, 3, step = 1)), fontsize = 13)
plt.xticks(ticks = (np.arange(-0.5, 3, step = 0.5)), fontsize = 13)
plt.legend(title = '', loc = 1)

#zoom
plt.xlim([-0.5, 2])
plt.ylim([-2, 2])

#save
plt.savefig(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Transfers/Profiles/smote+rund.png')
