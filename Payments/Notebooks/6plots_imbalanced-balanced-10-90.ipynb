# %%
#original dataset plot

# %%
#original frauds before synthetic generation
import pandas as pd

fraudsb = pd.read_csv(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Payments/Datasets/0frauds_payments_nd_corr.csv')

# %%
#how many frauds existed originally
len(fraudsb)
# Out:
# 252

# %%
#reduced amount of original nonfrauds 
nfraudsb = pd.read_csv(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Payments/Datasets/0nonfrauds_payments_nd_corr.csv', 
                       nrows = 10000)

# %%
#concat dataframe
ub_sample = pd.concat([fraudsb, nfraudsb], ignore_index = True)

# %%
#class ratios
ub_sample['is_fraud'].value_counts()/ub_sample.shape[0]
# Out:
# 0    0.975419
# 1    0.024581
# Name: is_fraud, dtype: float64

# %%
#plot imbalanced distribution
import seaborn as sns
import matplotlib.pylab as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

#variables
X = ub_sample[['amount', 'accountbalance', 'hour', 'week']]
y = ub_sample['is_fraud']

#scale data before PCA
pca = PCA()
pipe = Pipeline([('scaler', StandardScaler()), ('pca', pca)])
Xt = pipe.fit_transform(X)

#plot
sns.scatterplot(x = Xt[:, 0], y = Xt[:, 1], c = y, style = y, linewidth = 0.25, size = y, hue = y, sizes = {0: 50, 1:150},
                palette = {0: 'Blue', 1: 'Red'})

#legend
plt.xlabel('Component 1', fontsize = 14)
plt.ylabel('Component 2', fontsize = 14)
plt.yticks(fontsize = 13)
plt.xticks(fontsize = 13)
plt.legend(title = '')

#zoom
plt.xlim([-1, 5])
plt.ylim([-2, 3])

#save
plt.savefig(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Payments/Profiles/imbalanced_distribution.png')

# %%
#imbalanced dataset plot

# %%
#rund 10-90
import pandas as pd

rund_10_90 = pd.read_csv(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Payments/Datasets/2payments_rund_10-90.csv')

# %%
#class ratios
rund_10_90['is_fraud'].value_counts()/rund_10_90.shape[0]
# Out:
# 0    0.909091
# 1    0.090909
# Name: is_fraud, dtype: float64

# %%
#plot reduced 10-90 distribution
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

#variables
X = rund_10_90[['amount', 'accountbalance', 'hour', 'week']]
y = rund_10_90['is_fraud']

#scale data before PCA
pca = PCA()
pipe = Pipeline([('scaler', StandardScaler()), ('pca', pca)])
Xt = pipe.fit_transform(X)

#plot
sns.scatterplot(x = Xt[:, 0], y = Xt[:, 1], c = y, style = y, linewidth = 0.25, size = y, hue = y, sizes = {0: 50, 1:50},
                palette = {0: 'Blue', 1: 'Red'})

#legend
plt.xlabel('Component 1', fontsize = 14)
plt.ylabel('Component 2', fontsize = 14)
plt.yticks(fontsize = 13)
plt.xticks(fontsize = 13)
plt.legend(title = '')

#zoom
plt.xlim([-0.5, 2])
plt.ylim([-2, 2])

#save
plt.savefig(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Payments/Profiles/rund_10-90.png')

# %%
#balanced dataset plot - gan

# %%
#gan and rund - 50/50
import pandas as pd

gro = pd.read_csv(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Payments/Datasets/2payments_balanced_gan+rund.csv')

# %%
#number of transactions after the synthetic generation with ctgan
len(gro)

# %%
#select sample to plot
gr = gro.sample(n = 20000)

# %%
#class ratios
gr['is_fraud'].value_counts()/gr.shape[0]
# Out:
# 0    0.909091
# 1    0.090909
# Name: is_fraud, dtype: float64

# %%
#plot reduced 10-90 distribution
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

#variables
X = gr[['amount', 'accountbalance', 'hour', 'week']]
y = gr['is_fraud']

#scale data before PCA
pca = PCA()
pipe = Pipeline([('scaler', StandardScaler()), ('pca', pca)])
Xt = pipe.fit_transform(X)

#plot
sns.scatterplot(x = Xt[:, 0], y = Xt[:, 1], c = y, style = y, linewidth = 0.25, size = y, hue = y, sizes = {0: 50, 1:50},
                palette = {0: 'Blue', 1: 'Red'})

#legend
plt.xlabel('Component 1', fontsize = 14)
plt.ylabel('Component 2', fontsize = 14)
plt.yticks(fontsize = 13)
plt.xticks(fontsize = 13)
plt.legend(title = '')

#zoom
#plt.xlim([-0.5, 2])
#plt.ylim([-2, 2])

#save
#plt.savefig(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Payments/Profiles/gan+rund.png')

# %%
#balanced dataset plot - smote

# %%
#smote and rund - 50/50
import pandas as pd

sro = pd.read_csv(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Payments/Datasets/2payments_balanced_smote+rund.csv')

# %%
#number of transactions after the synthetic generation with smote
len(sro)

# %%
#select sample to plot
sr = sro.sample(n = 20000)

# %%
#class ratios
sr['is_fraud'].value_counts()/sr.shape[0]
# Out:
# 0    0.909091
# 1    0.090909
# Name: is_fraud, dtype: float64

# %%
#plot reduced 10-90 distribution
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

#variables
X = sr[['amount', 'accountbalance', 'hour', 'week']]
y = sr['is_fraud']

#scale data before PCA
pca = PCA()
pipe = Pipeline([('scaler', StandardScaler()), ('pca', pca)])
Xt = pipe.fit_transform(X)

#plot
sns.scatterplot(x = Xt[:, 0], y = Xt[:, 1], c = y, style = y, linewidth = 0.25, size = y, hue = y, sizes = {0: 50, 1:50},
                palette = {0: 'Blue', 1: 'Red'})

#legend
plt.xlabel('Component 1', fontsize = 14)
plt.ylabel('Component 2', fontsize = 14)
plt.yticks(fontsize = 13)
plt.xticks(fontsize = 13)
plt.legend(title = '')

#zoom
#plt.xlim([-0.5, 2])
#plt.ylim([-2, 2])

#save
#plt.savefig(r'C:/Users/BeatrizCarvalho/OneDrive - Closer Consultoria Lda/Documents/Entangled-Spaces/Payments/Profiles/gan+rund.png')
